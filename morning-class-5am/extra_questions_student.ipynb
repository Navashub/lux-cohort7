# %% [markdown]
# # Extra Practice Questions
# Python Foundations: Learn by Doing
# Lists • List Comprehension • Dictionaries • Dict Comprehension • Tuples • Sets • Set Operations
#
# Use the code cells below to answer each question. Type your solution in the answer cell, then run the cell to check your work.

# %% [markdown]
# ## Q1
# Create a list of 5 animals and print the 2nd and 4th animal.

# %%
# Create a list of 5 animals, then print the 2nd and 4th animal.
# Remember that list indexing starts at 0.
# Example: animals = ["cat", "dog", ...]

# %% [markdown]
# ## Q2
# You have a list of numbers. Replace the third item with 99.
# Starter code:
# `numbers = [10, 20, 30, 40, 50]`

# %%
numbers = [10, 20, 30, 40, 50]
# Replace the third item with 99 and print the list.

# %% [markdown]
# ## Q3
# Remove all duplicate values from this list and print the result as a sorted list.
# Starter code:
# `nums = [4, 2, 7, 2, 9, 4, 1, 7, 3]`

# %%
nums = [4, 2, 7, 2, 9, 4, 1, 7, 3]
# Remove duplicates, sort the list, and print the result.

# %% [markdown]
# ## Q4
# Combine two lists into one and print the total number of items.
# Starter code:
# `fruits = ["apple", "banana", "mango"]`
# `vegs = ["carrot", "onion", "tomato"]`

# %%
fruits = ["apple", "banana", "mango"]
vegs = ["carrot", "onion", "tomato"]
# Combine the lists and print the total number of items.

# %% [markdown]
# ## Q5
# Given a list of scores, print only the scores that are above 70.
# Starter code:
# `scores = [55, 82, 70, 91, 63, 78, 45, 88]`

# %%
scores = [55, 82, 70, 91, 63, 78, 45, 88]
# Print only the scores above 70.

# %% [markdown]
# ## Q6
# Reverse a list WITHOUT using `.reverse()` or `[::-1]`. Use a loop.
# Starter code:
# `items = [1, 2, 3, 4, 5]`

# %%
items = [1, 2, 3, 4, 5]
# Reverse the list using a loop and print the result.

# %% [markdown]
# ## Q7
# Find the sum and average of a list of numbers without using `sum()` or `len()`.
# Starter code:
# `data = [12, 45, 7, 23, 56, 34, 8]`

# %%
data = [12, 45, 7, 23, 56, 34, 8]
# Calculate the sum and average without using built-in sum() or len().

# %% [markdown]
# ## Q8
# Use list comprehension to create a list of numbers from 1 to 10 multiplied by 3.

# %%
# Use list comprehension to build the list and print it.

# %% [markdown]
# ## Q9
# Use list comprehension to extract only the words that start with the letter 'b' from a list of words.
# Starter code:
# `words = ["banana", "apple", "blueberry", "cherry", "berry", "avocado", "blackberry"]`

# %%
words = ["banana", "apple", "blueberry", "cherry", "berry", "avocado", "blackberry"]
# Use list comprehension to keep only the words that start with 'b'.

# %% [markdown]
# ## Q10
# Using list comprehension, create a list of tuples `(number, square)` for numbers 1–6. Example: `[(1, 1), (2, 4), ...]`

# %%
# Use list comprehension to build a list of tuples (number, square) for 1 through 6.

# %% [markdown]
# ## Q11
# Flatten this list of lists into one single list using list comprehension.
# Starter code:
# `nested = [[1, 2, 3], [4, 5], [6, 7, 8, 9]]`

# %%
nested = [[1, 2, 3], [4, 5], [6, 7, 8, 9]]
# Flatten the nested list into one list and print the result.
